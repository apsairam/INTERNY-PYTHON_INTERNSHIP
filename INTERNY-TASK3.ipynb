# %%
pip install pygame
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------------------------------------- 0.1/10.8 MB 3.2 MB/s eta 0:00:04
#    ---------------------------------------- 0.1/10.8 MB 2.4 MB/s eta 0:00:05
#    ---------------------------------------- 0.1/10.8 MB 2.4 MB/s eta 0:00:05
#    ---------------------------------------- 0.1/10.8 MB 2.4 MB/s eta 0:00:05
#    ---------------------------------------- 0.1/10.8 MB 2.4 MB/s eta 0:00:05
#    ---------------------------------------- 0.1/10.8 MB 2.4 MB/s eta 0:00:05
#    ---------------------------------------- 0.1/10.8 MB 2.4 MB/s eta 0:00:05
#    ---------------------------------------- 0.1/10.8 MB 2.4 MB/s eta 0:00:05
#    ---------------------------------------- 0.1/10.8 MB 2.4 MB/s eta 0:00:05
#    ---------------------------------------- 0.1/10.8 MB 2.4 MB/s eta 0:00:05
#     --------------------------------------- 0.2/10.8 MB 339.7 kB/s eta 0:00:32
# ...

# %%
import pygame
import random
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
SCREEN_HEIGHT = 400
SCREEN_WIDTH = 600
GRID_SIZE = 20
FPS = 5


#COLORS
WHITE = (255,255,255)
GREEN =(0,255,0)
RED = (255,0,0)

#DIRECTIONS
UP = (0,-1)
DOWN = (0,1)
LEFT = (-1,0)
RIGHT = (1,0)

# %%
class snakeGame:
    def __init__(self):
        pygame.init()
        self.screen = pygame.set_mode((SCREEN_WIDTH,SCREEN_HEIGHT))
        pygame.display.set_caption("Snake Game")
        self.clock = pygame.time.Clock()
        self.snake = [(SCREEN_WIDTH // 2, SCREEN_HEIGHT // 2)]
        self.direction = random.choice([UP,DOWN,LEFT,RIGHT])
        self.apple = self.generate_apple_position()
        self.score  =0
    def generate_apple_position(self):
        while True:
            x = random.randrange(0 , SCREEN_WIDTH, SCREEN_HEIGHT)
            y = random.randrange(0 , SCREEN_WIDTH, SCREEN_HEIGHT)
            if(x, y) not in self.snake:
                return x,y

    def run(self):
        running = True
        while running:
            for event in pygame.event.get():
                if event.type == pygame.QUIT:
                    running = False
                elif event.type == pygame.KEYDOWN:
                    if event.key == pygame.K_UP and self.direction != DOWN:
                        self.direction = UP
                    elif event.key == pygame.K_DOWN and self.direction != UP:
                        self.direction = DOWN
                    elif event.key == pygame.K_LEFT and self.direction != RIGHT:
                        self.direction = LEFT
                    elif event.key == pygame.K_RIGHT and self.direction != LEFT:
                        self.direction = RIGHT


           #move the snake
            head = (self.snake[0][0] + self.direction[0] * GRID_SIZE, self.snake[0][1] + self.direction[1] * GRID_SIZE )
            self.snake.insert(0, head)

            #collision check
            if head == self.apple:
                    self.score += 1
                    self.apple = self.generate_apple_position()
            else:
                self.snake.pop()

            if (
                head[0] < 0 or 
                head[0] >= SCREEN_WIDTH or 
                head[1] < 0 or 
                head[1] >= SCREEN_HEIGHT or
                head in self.snake[1:]
            ):
                running = False

            #Drawing 
        self.screen.fill(WHITE)
        for segment in self.snake:
            pygame.draw.rect(self.screen, GREEN, (segment[0], segment [1], GRID_SIZE, GRID_SIZE)) pygame.draw.rect(self.screen, RED, (self.apple[0], self.apple [1], GRID_SIZE, GRID_SIZE))

# Display score

        font pygame.font. SysFont(None, 30)
        text font.render(f"Score: (self.score)", True, (0, 0, 0))
        self.screen.blit(text, (10, 10))
        pygame.display.flip()
        self.clock.tick(FPS)
    pygame.quit()

if __name__ == "__main__":
    game = snakeGame()
    game.run()
# Out:
#   Cell In[6], line 58
#     pygame.draw.rect(self.screen, GREEN, (segment[0], segment [1], GRID_SIZE, GRID_SIZE)) pygame.draw.rect(self.screen, RED, (self.apple[0], self.apple [1], GRID_SIZE, GRID_SIZE))
#                                                                                           ^
# SyntaxError: invalid syntax

# %%
import pygame
import random

# Constants
SCREEN_HEIGHT = 400
SCREEN_WIDTH = 600
GRID_SIZE = 20
FPS = 5

# Colors
WHITE = (255, 255, 255)
GREEN = (0, 255, 0)
RED = (255, 0, 0)

# Directions
UP = (0, -1)
DOWN = (0, 1)
LEFT = (-1, 0)
RIGHT = (1, 0)

class snakeGame:
    def __init__(self):
        pygame.init()
        self.screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
        pygame.display.set_caption("Snake Game")
        self.clock = pygame.time.Clock()
        self.snake = [(SCREEN_WIDTH // 2, SCREEN_HEIGHT // 2)]
        self.direction = random.choice([UP, DOWN, LEFT, RIGHT])
        self.apple = self.generate_apple_position()
        self.score = 0

    def generate_apple_position(self):
        while True:
            x = random.randrange(0, SCREEN_WIDTH, GRID_SIZE)
            y = random.randrange(0, SCREEN_HEIGHT, GRID_SIZE)
            if (x, y) not in self.snake:
                return x, y

    def run(self):
        running = True
        while running:
            for event in pygame.event.get():
                if event.type == pygame.QUIT:
                    running = False
                elif event.type == pygame.KEYDOWN:
                    if event.key == pygame.K_UP and self.direction != DOWN:
                        self.direction = UP
                    elif event.key == pygame.K_DOWN and self.direction != UP:
                        self.direction = DOWN
                    elif event.key == pygame.K_LEFT and self.direction != RIGHT:
                        self.direction = LEFT
                    elif event.key == pygame.K_RIGHT and self.direction != LEFT:
                        self.direction = RIGHT

            # Move the snake
            head = (self.snake[0][0] + self.direction[0] * GRID_SIZE, self.snake[0][1] + self.direction[1] * GRID_SIZE)
            self.snake.insert(0, head)

            # Collision check
            if head == self.apple:
                self.score += 1
                self.apple = self.generate_apple_position()
            else:
                self.snake.pop()

            if (
                head[0] < 0 or 
                head[0] >= SCREEN_WIDTH or 
                head[1] < 0 or 
                head[1] >= SCREEN_HEIGHT or
                head in self.snake[1:]
            ):
                running = False

            # Drawing 
            self.screen.fill(WHITE)
            for segment in self.snake:
                pygame.draw.rect(self.screen, GREEN, (segment[0], segment[1], GRID_SIZE, GRID_SIZE))
            pygame.draw.rect(self.screen, RED, (self.apple[0], self.apple[1], GRID_SIZE, GRID_SIZE))

            # Display score
            font = pygame.font.SysFont(None, 30)
            text = font.render(f"Score: {self.score}", True, (0, 0, 0))
            self.screen.blit(text, (10, 10))
            pygame.display.flip()
            self.clock.tick(FPS)

        pygame.quit()

if __name__ == "__main__":
    game = snakeGame()
    game.run()
